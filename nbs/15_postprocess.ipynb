# %%
#| default_exp postprocess

# %% [markdown]
# # postprocess
#
# > Functionality to post-process already parsed data

# %%
#| export
import pathlib
import re

import pandas as pd

import sproc.structure

# %% [markdown]
# In order to avoid circular dependencies in the resulting *Python* modules, and since this is only for testing

# %%
import sproc.xml

# %% [markdown]
# ## Sample data

# %% [markdown]
# Directory where the data (*XML* files) are stored

# %%
directory = pathlib.Path.cwd().parent / 'samples'
assert directory.exists()
directory
# Out:
# PosixPath('/home/manu/Sync/UC3M/proyectos/2022/nextProcurement/sproc/samples')

# %% [markdown]
# A (sample) file in that directory

# %%
xml_file = directory / 'PlataformasAgregadasSinMenores_20220104_030016_1.atom'
assert xml_file.exists()
xml_file
# Out:
# PosixPath('/home/manu/Sync/UC3M/proyectos/2022/nextProcurement/sproc/samples/PlataformasAgregadasSinMenores_20220104_030016_1.atom')

# %%
df = sproc.xml.to_df(xml_file)
df
# Out:
#                                                     id  \
# 0    https://contrataciondelestado.es/sindicacion/P...
# 1    https://contrataciondelestado.es/sindicacion/P...
# 2    https://contrataciondelestado.es/sindicacion/P...
# 3    https://contrataciondelestado.es/sindicacion/P...
# 4    https://contrataciondelestado.es/sindicacion/P...
# ..                                                 ...
# 112  https://contrataciondelestado.es/sindicacion/P...
# 113  https://contrataciondelestado.es/sindicacion/P...
# 114  https://contrataciondelestado.es/sindicacion/P...
# 115  https://contrataciondelestado.es/sindicacion/P...
# 116  https://contrataciondelestado.es/sindicacion/P...
#
#                                                summary  \
# 0    Id licitación: C. 2-2021; Órgano de Contrataci...
# 1    Id licitación: 8128_3/2021; Órgano de Contrata...
# 2    Id licitación: 1000_0005-CP01-2021-000063; Órg...
# 3    Id licitación: 1379/2020 4738; Órgano de Contr...
# 4    Id licitación: 2021-44; Órgano de Contratación...
# ..                                                 ...
# 112  Id licitación: 1005_391-2021; Órgano de Contra...
# 113  Id licitación: 8165_3/2021; Órgano de Contrata...
# 114  Id licitación: 8113_3/2021; Órgano de Contrata...
# 115  Id licitación: 8113_01 2021; Órgano de Contrat...
# 116  Id licitación: 0001264/2021; Órgano de contrat...
#
#                                                  title  \
# 0    L'objecte del contracte és la renovació de tot...
# 1    Obras de restauración hidromorfológica del río...
# 2    Contrato del servicio de realización de labore...
# 3    Obres de renovació de l'enllumenat públic a la...
# 4    Subministre i la instal·lació fotovoltaica en ...
# ..                                                 ...
# 112  Apoyo a la gestión del patrimonio filmográfico...
# 113  Asistencia técnica para la prestación del serv...
# 114  Contrato de servicios de desinfección, desinse...
# 115  Contrato del Servicio de Teleasistencia para l...
# 116  2021/pa-44-4 servicio de mantenimiento integra...
#
#                            updated ContractFolderStatus - ContractFolderID  \
# 0    2022-01-03T01:11:41.826+01:00                               C. 2-2021
# 1    2022-01-03T01:00:11.194+01:00                             8128_3/2021
# 2    2022-01-03T01:00:10.399+01:00              1000_0005-CP01-2021-000063
# 3    2022-01-03T00:11:40.740+01:00                          1379/2020 4738
# 4    2022-01-03T00:11:40.696+01:00                                 2021-44
# ..                             ...                                     ...
# 112  2021-12-31T01:00:14.946+01:00                           1005_391-2021
# 113  2021-12-31T01:00:14.393+01:00                             8165_3/2021
# 114  2021-12-31T01:00:13.594+01:00                             8113_3/2021
# 115  2021-12-31T01:00:12.604+01:00                            8113_01 2021
# 116  2021-12-31T00:14:15.739+01:00                            0001264/2021
#
#     ContractFolderStatus - ContractFolderStatusCode  \
# 0                                               ADJ
# 1                                               PUB
# 2                                                EV
# 3                                                EV
# 4                                                EV
# ..                                              ...
# 112                                             PUB
# 113                                              EV
# 114                                              EV
# 115                                              EV
# 116                                             RES
#
#     ContractFolderStatus - LocatedContractingParty - BuyerProfileURIID  \
# 0    https://contractaciopublica.gencat.cat/ecofin_...
# 1                                                  NaN
# 2                                                  NaN
# 3    https://contractaciopublica.gencat.cat/ecofin_...
# 4    https://contractaciopublica.gencat.cat/ecofin_...
# ..                                                 ...
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
#
#     ContractFolderStatus - LocatedContractingParty - Party - PartyName - Name  \
# 0                             Ajuntament de Sant Ramon
# 1                               Pleno del Ayuntamiento
# 2    El Director General de Comunicación y Relacion...
# 3                           Ajuntament de Canet de Mar
# 4                                  Ajuntament de Valls
# ..                                                 ...
# 112  Dirección General de Cultura-Institución Prínc...
# 113  Mancomunidad de Servicios Sociales de Base de ...
# 114                  Subdirector de Gestión y Recursos
# 115  Agencia Navarra de Autonomía y Desarrollo de l...
# 116  Agencia Pública Empresarial Sanitaria Bajo Gua...
#
#     ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - PartyName - Name  \
# 0                     Entitats municipals de Catalunya
# 1                              AYUNTAMIENTO DE MONREAL
# 2    Departamento de Presidencia, Igualdad, Función...
# 3                     Entitats municipals de Catalunya
# 4                     Entitats municipals de Catalunya
# ..                                                 ...
# 112        Departamento de Cultura, Deporte y Juventud
# 113  MANCOMUNIDAD DE SERVICIOS DE HUARTE Y DE ESTER...
# 114                Agencia Navarra para la Dependencia
# 115                Agencia Navarra para la Dependencia
# 116                                 Junta de Andalucía
#
#       ContractFolderStatus - ProcurementProject - Name  ...  \
# 0    L'objecte del contracte és la renovació de tot...  ...
# 1    Obras de restauración hidromorfológica del río...  ...
# 2    Contrato del servicio de realización de labore...  ...
# 3    Obres de renovació de l'enllumenat públic a la...  ...
# 4    Subministre i la instal·lació fotovoltaica en ...  ...
# ..                                                 ...  ...
# 112  Apoyo a la gestión del patrimonio filmográfico...  ...
# 113  Asistencia técnica para la prestación del serv...  ...
# 114  Contrato de servicios de desinfección, desinse...  ...
# 115  Contrato del Servicio de Teleasistencia para l...  ...
# 116  2021/pa-44-4 servicio de mantenimiento integra...  ...
#
#     ContractFolderStatus - LegalDocumentReference - Attachment - ExternalReference - URI  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    https://contractaciopublica.gencat.cat/ecofin_...
# 4    https://contractaciopublica.gencat.cat/ecofin_...
# ..                                                 ...
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
#
#     ContractFolderStatus - TechnicalDocumentReference - ID  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                  Enllac plec clausules tecniques.doc
# ..                                                 ...
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
#
#     ContractFolderStatus - TechnicalDocumentReference - Attachment - ExternalReference - URI  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    https://contractaciopublica.gencat.cat/ecofin_...
# ..                                                 ...
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
#
#     ContractFolderStatus - ProcurementProject - PlannedPeriod - StartDate  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 112                                                NaN
# 113                                                NaN
# 114                                         2022-01-01
# 115                                                NaN
# 116                                                NaN
#
#     ContractFolderStatus - ProcurementProject - PlannedPeriod - EndDate  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 112                                                NaN
# 113                                                NaN
# 114                                         2022-12-31
# 115                                                NaN
# 116                                                NaN
#
#     ContractFolderStatus - LocatedContractingParty - Party - PartyIdentification - ID  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
#
#     ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - ParentLocatedParty - PartyName - Name  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
#
#     ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndDate  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
#
#     ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndTime  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
#
#     ContractFolderStatus - TenderResult - AwardedTenderedProject - ProcurementProjectLotID
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
#
# [117 rows x 38 columns]

# %% [markdown]
# There are some *multivalued* columns

# %%
sproc.structure.multivalued_columns(df)
# Out:
# ['ContractFolderStatus - ProcurementProject - RequiredCommodityClassification - ItemClassificationCode',
#  'ContractFolderStatus - TenderResult - ResultCode',
#  'ContractFolderStatus - TenderResult - ReceivedTenderQuantity',
#  'ContractFolderStatus - TenderResult - WinningParty - PartyIdentification - ID',
#  'ContractFolderStatus - TenderResult - WinningParty - PartyName - Name',
#  'ContractFolderStatus - TenderResult - AwardedTenderedProject - LegalMonetaryTotal - TaxExclusiveAmount',
#  'ContractFolderStatus - ValidNoticeInfo - NoticeTypeCode',
#  'ContractFolderStatus - ValidNoticeInfo - AdditionalPublicationStatus - PublicationMediaName',
#  'ContractFolderStatus - ValidNoticeInfo - AdditionalPublicationStatus - AdditionalPublicationDocumentReference - IssueDate',
#  'ContractFolderStatus - TenderResult - AwardedTenderedProject - ProcurementProjectLotID']

# %% [markdown]
# ## Columns' types

# %% [markdown]
# A regular expression matching any column whose final component is `PostalZone`

# %%
#| export
re_postal_zone = re.compile(sproc.structure.assemble_name(['.*', 'PostalZone$']))
re_postal_zone
# Out:
# re.compile(r'.* - PostalZone$', re.UNICODE)

# %% [markdown]
# For instance

# %%
re_postal_zone.match('foo - PostalZone')
# Out:
# <re.Match object; span=(0, 16), match='foo - PostalZone'>

# %% [markdown]
# but

# %%
re_postal_zone.match('Address - Number')

# %% [markdown]
# Two positives

# %%
assert re_postal_zone.match(sproc.structure.assemble_name(['ContractFolderStatus', 'ProcurementProject', 'RealizedLocation', 'Address', 'PostalZone']))
assert re_postal_zone.match(sproc.structure.assemble_name(['ContractFolderStatus', 'LocatedContractingParty', 'Party', 'PostalAddress', 'PostalZone']))

# %% [markdown]
# A negative

# %%
assert not re_postal_zone.match(sproc.structure.assemble_name(['ContractFolderStatus', 'Wap']))

# %% [markdown]
# The list below specifies fields that are to be interpreted as `str`

# %%
#| export
# str_columns = [['ContractFolderStatus', 'LocatedContractingParty', 'Party', 'PostalAddress', 'PostalZone']]
str_columns = []

# %%
str_columns[:2]
# Out:
# []

# %% [markdown]
# For easier processing, the `list`s are turned into `str`

# %%
#| export
assembled_str_columns = [sproc.structure.assemble_name(c) for c in str_columns]

# %%
assembled_str_columns
# Out:
# []

# %% [markdown]
# These columns, if present,

# %%
deadline_date_col = sproc.structure.assemble_name(['ContractFolderStatus', 'TenderingProcess','TenderSubmissionDeadlinePeriod','EndDate'])
deadline_time_col = sproc.structure.assemble_name(['ContractFolderStatus', 'TenderingProcess','TenderSubmissionDeadlinePeriod','EndTime'])

# %% [markdown]
# are parsed *jointly* into a new column

# %%
deadline_datetime_col = sproc.structure.assemble_name(['ContractFolderStatus', 'TenderingProcess', 'TenderSubmissionDeadlinePeriod'])

# %% [markdown]
# A function to tidy up some things in the `pd.DataFrame`s returned by `sproc.xml.to_df`

# %%
#| export
def typecast_columns(input_df: pd.DataFrame) -> pd.DataFrame:
    """
    Tidy up the `pd.DataFrame` returned by `to_df`.
    
    **Parameters**
    
    - input_df: pd.DataFrame
    
        Input DataFrame as ready by `to_df`.
    
    **Returns**
    
    - out: pd.DataFrame
    
        Post-processed DataFrame.
    
    """
    
    res = input_df.copy()
    
    processed_columns = []
    
    # ------------ ContractFolderStatus - TenderingProcess - TenderSubmissionDeadlinePeriod ------------
    
    # columns containing the end date and time
    date_col = sproc.structure.assemble_name(['ContractFolderStatus', 'TenderingProcess','TenderSubmissionDeadlinePeriod','EndDate'])
    time_col = sproc.structure.assemble_name(['ContractFolderStatus', 'TenderingProcess','TenderSubmissionDeadlinePeriod','EndTime'])
    
    # only if they are present in the `pd.DataFrame`...
    if (date_col in res) and (time_col in res):
        
        new_column = sproc.structure.assemble_name(['ContractFolderStatus', 'TenderingProcess', 'TenderSubmissionDeadlinePeriod'])
    
        # we don't want to inadvertently overwrite an existing column
        assert new_column not in res
    
        res[new_column] = pd.to_datetime(input_df[date_col] + 'T' + input_df[time_col], format='%Y-%m-%dT%H:%M:%S', utc=True, errors='coerce')   
    
        processed_columns.append(new_column)
    
    # NOTE: one could also delete the original columns being parsed, but they might be useful if errors happen during conversion (`errors=coerce`)
    
    # -------------------------------------------- updated ---------------------------------------------
    
    res['updated'] = pd.to_datetime(input_df['updated'], format='%Y-%m-%dT%H:%M:%S.%f%z', utc=True)
    
    processed_columns.append('updated')
    
    # ---------------------------------------- string columns ------------------------------------------
    
#     for c in assembled_str_columns:
        
#         if c in res:
        
#             res[c] = res[c].astype(pd.StringDtype())

#             processed_columns.append(c)
    
    # --------------------------------------- everything else ------------------------------------------
    
    for c in res.columns:
        
        # if this column has already been processed...
        if c in processed_columns:
            
            continue
            
        # if this column is *multivalued*...
        if sproc.structure.is_multivalued(res[c]):
            
            continue
            
        if re_postal_zone.match(c):
            
            res[c] = res[c].astype(pd.StringDtype())
            # print(f'converting {c}')
            
            continue
            
        # an attempt is made...
        try:
            
            # to interpret every column as a (float) number
            res[c] = res[c].astype(float)
        
        # if conversion to float is not feasible...
        except (TypeError, ValueError):
            
            # ...the column is taken to be one of strings
            res[c] = res[c].astype(pd.StringDtype())
    
    return res

# %%
post_df = typecast_columns(df)
post_df.head()
# Out:
#                                                   id  \
# 0  https://contrataciondelestado.es/sindicacion/P...
# 1  https://contrataciondelestado.es/sindicacion/P...
# 2  https://contrataciondelestado.es/sindicacion/P...
# 3  https://contrataciondelestado.es/sindicacion/P...
# 4  https://contrataciondelestado.es/sindicacion/P...
#
#                                              summary  \
# 0  Id licitación: C. 2-2021; Órgano de Contrataci...
# 1  Id licitación: 8128_3/2021; Órgano de Contrata...
# 2  Id licitación: 1000_0005-CP01-2021-000063; Órg...
# 3  Id licitación: 1379/2020 4738; Órgano de Contr...
# 4  Id licitación: 2021-44; Órgano de Contratación...
#
#                                                title  \
# 0  L'objecte del contracte és la renovació de tot...
# 1  Obras de restauración hidromorfológica del río...
# 2  Contrato del servicio de realización de labore...
# 3  Obres de renovació de l'enllumenat públic a la...
# 4  Subministre i la instal·lació fotovoltaica en ...
#
#                            updated ContractFolderStatus - ContractFolderID  \
# 0 2022-01-03 00:11:41.826000+00:00                               C. 2-2021
# 1 2022-01-03 00:00:11.194000+00:00                             8128_3/2021
# 2 2022-01-03 00:00:10.399000+00:00              1000_0005-CP01-2021-000063
# 3 2022-01-02 23:11:40.740000+00:00                          1379/2020 4738
# 4 2022-01-02 23:11:40.696000+00:00                                 2021-44
#
#   ContractFolderStatus - ContractFolderStatusCode  \
# 0                                             ADJ
# 1                                             PUB
# 2                                              EV
# 3                                              EV
# 4                                              EV
#
#   ContractFolderStatus - LocatedContractingParty - BuyerProfileURIID  \
# 0  https://contractaciopublica.gencat.cat/ecofin_...
# 1                                               <NA>
# 2                                               <NA>
# 3  https://contractaciopublica.gencat.cat/ecofin_...
# 4  https://contractaciopublica.gencat.cat/ecofin_...
#
#   ContractFolderStatus - LocatedContractingParty - Party - PartyName - Name  \
# 0                           Ajuntament de Sant Ramon
# 1                             Pleno del Ayuntamiento
# 2  El Director General de Comunicación y Relacion...
# 3                         Ajuntament de Canet de Mar
# 4                                Ajuntament de Valls
#
#   ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - PartyName - Name  \
# 0                   Entitats municipals de Catalunya
# 1                            AYUNTAMIENTO DE MONREAL
# 2  Departamento de Presidencia, Igualdad, Función...
# 3                   Entitats municipals de Catalunya
# 4                   Entitats municipals de Catalunya
#
#     ContractFolderStatus - ProcurementProject - Name  ...  \
# 0  L'objecte del contracte és la renovació de tot...  ...
# 1  Obras de restauración hidromorfológica del río...  ...
# 2  Contrato del servicio de realización de labore...  ...
# 3  Obres de renovació de l'enllumenat públic a la...  ...
# 4  Subministre i la instal·lació fotovoltaica en ...  ...
#
#    ContractFolderStatus - TechnicalDocumentReference - ID  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                Enllac plec clausules tecniques.doc
#
#    ContractFolderStatus - TechnicalDocumentReference - Attachment - ExternalReference - URI  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4  https://contractaciopublica.gencat.cat/ecofin_...
#
#    ContractFolderStatus - ProcurementProject - PlannedPeriod - StartDate  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
#
#   ContractFolderStatus - ProcurementProject - PlannedPeriod - EndDate  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
#
#   ContractFolderStatus - LocatedContractingParty - Party - PartyIdentification - ID  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
#
#    ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - ParentLocatedParty - PartyName - Name  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
#
#   ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndDate  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
#
#   ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndTime  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
# 3                                               <NA>
# 4                                               <NA>
#
#   ContractFolderStatus - TenderResult - AwardedTenderedProject - ProcurementProjectLotID  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ContractFolderStatus - TenderingProcess - TenderSubmissionDeadlinePeriod
# 0                          2021-12-17 14:00:00+00:00
# 1                          2022-01-22 23:30:00+00:00
# 2                                                NaT
# 3                          2022-01-02 23:59:00+00:00
# 4                          2022-01-02 23:59:00+00:00
#
# [5 rows x 39 columns]

# %% [markdown]
# After post-processing some `object`s have been parsed as dates.

# %%
post_df.dtypes[:5]
# Out:
# id                                                      string
# summary                                                 string
# title                                                   string
# updated                                    datetime64[ns, UTC]
# ContractFolderStatus - ContractFolderID                 string
# dtype: object

# %% [markdown]
# *Multivalued* columns are still *multivalued*

# %%
assert sproc.structure.multivalued_columns(post_df) == sproc.structure.multivalued_columns(df)

# %% [markdown]
# ## Most recent update

# %% [markdown]
# *updated*, **after post-processing** is apt for ordering

# %%
post_df['updated'].dtype
# Out:
# datetime64[ns, UTC]

# %% [markdown]
# We order the entries by *updated* date (ascending order) and then  group by *id*

# %%
grouped = post_df.sort_values('updated').groupby('id')

# %% [markdown]
# We are interested in groups with more than one element

# %%
not_one_element_group = (grouped.size() > 1)
not_one_element_group
# Out:
# id
# https://contrataciondelestado.es/sindicacion/P...    False
# https://contrataciondelestado.es/sindicacion/P...    False
# https://contrataciondelestado.es/sindicacion/P...    False
# https://contrataciondelestado.es/sindicacion/P...    False
# https://contrataciondelestado.es/sindicacion/P...    False
#                                                      ...
# https://contrataciondelestado.es/sindicacion/P...    False
# https://contrataciondelestado.es/sindicacion/P...    False
# https://contrataciondelestado.es/sindicacion/P...    False
# https://contrataciondelestado.es/sindicacion/P...    False
# https://contrataciondelestado.es/sindicacion/P...    False
# Length: 115, dtype: bool

# %% [markdown]
# Number of tenders with updates

# %%
not_one_element_group.sum()
# Out:
# 2

# %%
actual_groups = not_one_element_group.index[not_one_element_group]
actual_groups
# Out:
# Index(['https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/8904280', 'https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/8994209'], dtype='string', name='id')

# %% [markdown]
# There is a group with this number of elements

# %%
grouped.size().max()
# Out:
# 2

# %% [markdown]
# For getting groups with *exactly* a certain number of elements (here $2$ again)

# %%
size_2_groups = (grouped.size() == 2).loc[lambda x: x].index
size_2_groups
# Out:
# Index(['https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/8904280', 'https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/8994209'], dtype='string', name='id')

# %%
first_group = grouped.get_group(actual_groups[0])
first_group
# Out:
#                                                    id  \
# 32  https://contrataciondelestado.es/sindicacion/P...
# 19  https://contrataciondelestado.es/sindicacion/P...
#
#                                               summary  \
# 32  Id licitación: 3069_1/2021; Órgano de Contrata...
# 19  Id licitación: 3069_1/2021; Órgano de Contrata...
#
#                                                 title  \
# 32  Construcción de depósito regulador de 100m3 en...
# 19  Construcción de depósito regulador de 100m3 en...
#
#                             updated ContractFolderStatus - ContractFolderID  \
# 32 2022-01-01 00:00:16.761000+00:00                             3069_1/2021
# 19 2022-01-01 07:30:09.698000+00:00                             3069_1/2021
#
#    ContractFolderStatus - ContractFolderStatusCode  \
# 32                                              EV
# 19                                              EV
#
#    ContractFolderStatus - LocatedContractingParty - BuyerProfileURIID  \
# 32                                               <NA>
# 19                                               <NA>
#
#    ContractFolderStatus - LocatedContractingParty - Party - PartyName - Name  \
# 32                                CONCEJO DE GALBARRA
# 19                                CONCEJO DE GALBARRA
#
#    ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - PartyName - Name  \
# 32                                Concejo de Galbarra
# 19                                Concejo de Galbarra
#
#      ContractFolderStatus - ProcurementProject - Name  ...  \
# 32  Construcción de depósito regulador de 100m3 en...  ...
# 19  Construcción de depósito regulador de 100m3 en...  ...
#
#     ContractFolderStatus - TechnicalDocumentReference - ID  \
# 32                                               <NA>
# 19                                               <NA>
#
#     ContractFolderStatus - TechnicalDocumentReference - Attachment - ExternalReference - URI  \
# 32                                               <NA>
# 19                                               <NA>
#
#     ContractFolderStatus - ProcurementProject - PlannedPeriod - StartDate  \
# 32                                               <NA>
# 19                                               <NA>
#
#    ContractFolderStatus - ProcurementProject - PlannedPeriod - EndDate  \
# 32                                               <NA>
# 19                                               <NA>
#
#    ContractFolderStatus - LocatedContractingParty - Party - PartyIdentification - ID  \
# 32                                               <NA>
# 19                                               <NA>
#
#     ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - ParentLocatedParty - PartyName - Name  \
# 32                                               <NA>
# 19                                               <NA>
#
#    ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndDate  \
# 32                                               <NA>
# 19                                               <NA>
#
#    ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndTime  \
# 32                                               <NA>
# 19                                               <NA>
#
#    ContractFolderStatus - TenderResult - AwardedTenderedProject - ProcurementProjectLotID  \
# 32                                                NaN
# 19                                                NaN
#
#    ContractFolderStatus - TenderingProcess - TenderSubmissionDeadlinePeriod
# 32                                                NaT
# 19                                                NaT
#
# [2 rows x 39 columns]

# %% [markdown]
# `True` if columns are different across elements

# %%
columns_are_different = first_group.iloc[0] != first_group.iloc[-1]
columns_are_different
# Out:
# id                                                                                                                           False
# summary                                                                                                                      False
# title                                                                                                                        False
# updated                                                                                                                       True
# ContractFolderStatus - ContractFolderID                                                                                      False
# ContractFolderStatus - ContractFolderStatusCode                                                                              False
# ContractFolderStatus - LocatedContractingParty - BuyerProfileURIID                                                            True
# ContractFolderStatus - LocatedContractingParty - Party - PartyName - Name                                                    False
# ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - PartyName - Name                                       False
# ContractFolderStatus - ProcurementProject - Name                                                                             False
# ContractFolderStatus - ProcurementProject - TypeCode                                                                         False
# ContractFolderStatus - ProcurementProject - BudgetAmount - EstimatedOverallContractAmount                                    False
# ContractFolderStatus - ProcurementProject - BudgetAmount - TaxExclusiveAmount                                                False
# ContractFolderStatus - ProcurementProject - RequiredCommodityClassification - ItemClassificationCode                         False
# ContractFolderStatus - ProcurementProject - RealizedLocation - CountrySubentityCode                                          False
# ContractFolderStatus - ProcurementProject - PlannedPeriod - DurationMeasure                                                  False
# ContractFolderStatus - TenderResult - ResultCode                                                                              True
# ContractFolderStatus - TenderResult - ReceivedTenderQuantity                                                                  True
# ContractFolderStatus - TenderResult - WinningParty - PartyIdentification - ID                                                 True
# ContractFolderStatus - TenderResult - WinningParty - PartyName - Name                                                         True
# ContractFolderStatus - TenderResult - AwardedTenderedProject - LegalMonetaryTotal - TaxExclusiveAmount                        True
# ContractFolderStatus - TenderingProcess - ProcedureCode                                                                      False
# ContractFolderStatus - TenderingProcess - TenderSubmissionDeadlinePeriod - EndDate                                            True
# ContractFolderStatus - TenderingProcess - TenderSubmissionDeadlinePeriod - EndTime                                            True
# ContractFolderStatus - ValidNoticeInfo - NoticeTypeCode                                                                      False
# ContractFolderStatus - ValidNoticeInfo - AdditionalPublicationStatus - PublicationMediaName                                  False
# ContractFolderStatus - ValidNoticeInfo - AdditionalPublicationStatus - AdditionalPublicationDocumentReference - IssueDate     True
# ContractFolderStatus - LegalDocumentReference - ID                                                                            True
# ContractFolderStatus - LegalDocumentReference - Attachment - ExternalReference - URI                                          True
# ContractFolderStatus - TechnicalDocumentReference - ID                                                                        True
# ContractFolderStatus - TechnicalDocumentReference - Attachment - ExternalReference - URI                                      True
# ContractFolderStatus - ProcurementProject - PlannedPeriod - StartDate                                                         True
# ContractFolderStatus - ProcurementProject - PlannedPeriod - EndDate                                                           True
# ContractFolderStatus - LocatedContractingParty - Party - PartyIdentification - ID                                             True
# ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - ParentLocatedParty - PartyName - Name                   True
# ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndDate                                       True
# ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndTime                                       True
# ContractFolderStatus - TenderResult - AwardedTenderedProject - ProcurementProjectLotID                                        True
# ContractFolderStatus - TenderingProcess - TenderSubmissionDeadlinePeriod                                                      True
# dtype: bool

# %% [markdown]
# The values in those columns are (besides *updated*) all `nan`s

# %%
first_group[first_group.columns[columns_are_different]]
# Out:
#                             updated  \
# 32 2022-01-01 00:00:16.761000+00:00
# 19 2022-01-01 07:30:09.698000+00:00
#
#    ContractFolderStatus - LocatedContractingParty - BuyerProfileURIID  \
# 32                                               <NA>
# 19                                               <NA>
#
#    ContractFolderStatus - TenderResult - ResultCode  \
# 32                                              NaN
# 19                                              NaN
#
#    ContractFolderStatus - TenderResult - ReceivedTenderQuantity  \
# 32                                                NaN
# 19                                                NaN
#
#    ContractFolderStatus - TenderResult - WinningParty - PartyIdentification - ID  \
# 32                                                NaN
# 19                                                NaN
#
#    ContractFolderStatus - TenderResult - WinningParty - PartyName - Name  \
# 32                                                NaN
# 19                                                NaN
#
#    ContractFolderStatus - TenderResult - AwardedTenderedProject - LegalMonetaryTotal - TaxExclusiveAmount  \
# 32                                                NaN
# 19                                                NaN
#
#    ContractFolderStatus - TenderingProcess - TenderSubmissionDeadlinePeriod - EndDate  \
# 32                                               <NA>
# 19                                               <NA>
#
#    ContractFolderStatus - TenderingProcess - TenderSubmissionDeadlinePeriod - EndTime  \
# 32                                               <NA>
# 19                                               <NA>
#
#    ContractFolderStatus - ValidNoticeInfo - AdditionalPublicationStatus - AdditionalPublicationDocumentReference - IssueDate  \
# 32  [2021-12-16, 2021-12-16, 2021-12-16, 2021-12-1...
# 19  [2021-12-16, 2021-12-16, 2021-12-16, 2021-12-1...
#
#     ... ContractFolderStatus - TechnicalDocumentReference - ID  \
# 32  ...                                               <NA>
# 19  ...                                               <NA>
#
#    ContractFolderStatus - TechnicalDocumentReference - Attachment - ExternalReference - URI  \
# 32                                               <NA>
# 19                                               <NA>
#
#    ContractFolderStatus - ProcurementProject - PlannedPeriod - StartDate  \
# 32                                               <NA>
# 19                                               <NA>
#
#    ContractFolderStatus - ProcurementProject - PlannedPeriod - EndDate  \
# 32                                               <NA>
# 19                                               <NA>
#
#    ContractFolderStatus - LocatedContractingParty - Party - PartyIdentification - ID  \
# 32                                               <NA>
# 19                                               <NA>
#
#    ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - ParentLocatedParty - PartyName - Name  \
# 32                                               <NA>
# 19                                               <NA>
#
#    ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndDate  \
# 32                                               <NA>
# 19                                               <NA>
#
#    ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndTime  \
# 32                                               <NA>
# 19                                               <NA>
#
#    ContractFolderStatus - TenderResult - AwardedTenderedProject - ProcurementProjectLotID  \
# 32                                                NaN
# 19                                                NaN
#
#    ContractFolderStatus - TenderingProcess - TenderSubmissionDeadlinePeriod
# 32                                                NaT
# 19                                                NaT
#
# [2 rows x 22 columns]

# %% [markdown]
# Only the last element of each group (the most recent entry) is kept

# %%
only_last_update_df = grouped.last()
only_last_update_df.head()
# Out:
#                                                                                              summary  \
# id
# https://contrataciondelestado.es/sindicacion/P...  Id licitación: 6011900114;Órgano de Contrataci...
# https://contrataciondelestado.es/sindicacion/P...  Id licitación: 11/2019; Órgano de Contratació...
# https://contrataciondelestado.es/sindicacion/P...  Id licitación: 6012000208;Órgano de Contrataci...
# https://contrataciondelestado.es/sindicacion/P...  Id licitación: 6012100119;Órgano de Contrataci...
# https://contrataciondelestado.es/sindicacion/P...  Id Licitación: PcPG/2021/801758, Órgano de Con...
#
#                                                                                                title  \
# id
# https://contrataciondelestado.es/sindicacion/P...  Servicio de migración de los productos BMC ins...
# https://contrataciondelestado.es/sindicacion/P...  Concurso de proyectos para la rehabilitación u...
# https://contrataciondelestado.es/sindicacion/P...  Suministro de equipos de manutención (carretil...
# https://contrataciondelestado.es/sindicacion/P...  Servicio de soporte al mantenimiento de instal...
# https://contrataciondelestado.es/sindicacion/P...  Servicio para la caracterización hidromorfolóx...
#
#                                                                            updated  \
# id
# https://contrataciondelestado.es/sindicacion/P... 2021-12-31 10:56:15.855000+00:00
# https://contrataciondelestado.es/sindicacion/P... 2021-12-31 10:41:20.201000+00:00
# https://contrataciondelestado.es/sindicacion/P... 2021-12-31 11:11:15.851000+00:00
# https://contrataciondelestado.es/sindicacion/P... 2021-12-31 10:11:16.027000+00:00
# https://contrataciondelestado.es/sindicacion/P... 2022-01-02 22:11:15.096000+00:00
#
#                                                   ContractFolderStatus - ContractFolderID  \
# id
# https://contrataciondelestado.es/sindicacion/P...                              6011900114
# https://contrataciondelestado.es/sindicacion/P...                                 11/2019
# https://contrataciondelestado.es/sindicacion/P...                              6012000208
# https://contrataciondelestado.es/sindicacion/P...                              6012100119
# https://contrataciondelestado.es/sindicacion/P...                        PcPG/2021/801758
#
#                                                   ContractFolderStatus - ContractFolderStatusCode  \
# id
# https://contrataciondelestado.es/sindicacion/P...                                             RES
# https://contrataciondelestado.es/sindicacion/P...                                              EV
# https://contrataciondelestado.es/sindicacion/P...                                             RES
# https://contrataciondelestado.es/sindicacion/P...                                             RES
# https://contrataciondelestado.es/sindicacion/P...                                             RES
#
#                                                   ContractFolderStatus - LocatedContractingParty - BuyerProfileURIID  \
# id
# https://contrataciondelestado.es/sindicacion/P...  http://www.madrid.org/cs/Satellite?cid=1204201...
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...  http://www.madrid.org/cs/Satellite?cid=1204201...
# https://contrataciondelestado.es/sindicacion/P...  http://www.madrid.org/cs/Satellite?cid=1204201...
# https://contrataciondelestado.es/sindicacion/P...  https://www.contratosdegalicia.gal//consultaOr...
#
#                                                   ContractFolderStatus - LocatedContractingParty - Party - PartyName - Name  \
# id
# https://contrataciondelestado.es/sindicacion/P...           Empresa Pública de Metro de Madrid, S.A.
# https://contrataciondelestado.es/sindicacion/P...                                           Alcaldia
# https://contrataciondelestado.es/sindicacion/P...           Empresa Pública de Metro de Madrid, S.A.
# https://contrataciondelestado.es/sindicacion/P...           Empresa Pública de Metro de Madrid, S.A.
# https://contrataciondelestado.es/sindicacion/P...          Ente Público Empresarial Augas de Galicia
#
#                                                   ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - PartyName - Name  \
# id
# https://contrataciondelestado.es/sindicacion/P...       Consejería de Transportes e Infraestructuras
# https://contrataciondelestado.es/sindicacion/P...                              Ayuntamiento de Leioa
# https://contrataciondelestado.es/sindicacion/P...       Consejería de Transportes e Infraestructuras
# https://contrataciondelestado.es/sindicacion/P...       Consejería de Transportes e Infraestructuras
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
#
#                                                     ContractFolderStatus - ProcurementProject - Name  \
# id
# https://contrataciondelestado.es/sindicacion/P...  Servicio de migración de los productos BMC ins...
# https://contrataciondelestado.es/sindicacion/P...  Concurso de proyectos para la rehabilitación u...
# https://contrataciondelestado.es/sindicacion/P...  Suministro de equipos de manutención (carretil...
# https://contrataciondelestado.es/sindicacion/P...  Servicio de soporte al mantenimiento de instal...
# https://contrataciondelestado.es/sindicacion/P...  Servicio para la caracterización hidromorfolóx...
#
#                                                    ContractFolderStatus - ProcurementProject - TypeCode  \
# id
# https://contrataciondelestado.es/sindicacion/P...                                                2.0
# https://contrataciondelestado.es/sindicacion/P...                                                2.0
# https://contrataciondelestado.es/sindicacion/P...                                                1.0
# https://contrataciondelestado.es/sindicacion/P...                                                2.0
# https://contrataciondelestado.es/sindicacion/P...                                                2.0
#
#                                                    ...  \
# id                                                 ...
# https://contrataciondelestado.es/sindicacion/P...  ...
# https://contrataciondelestado.es/sindicacion/P...  ...
# https://contrataciondelestado.es/sindicacion/P...  ...
# https://contrataciondelestado.es/sindicacion/P...  ...
# https://contrataciondelestado.es/sindicacion/P...  ...
#
#                                                    ContractFolderStatus - TechnicalDocumentReference - ID  \
# id
# https://contrataciondelestado.es/sindicacion/P...                                  1354764548025.pdf
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                  1354836373815.pdf
# https://contrataciondelestado.es/sindicacion/P...                                  1354874714036.pdf
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
#
#                                                    ContractFolderStatus - TechnicalDocumentReference - Attachment - ExternalReference - URI  \
# id
# https://contrataciondelestado.es/sindicacion/P...  http://www.madrid.org/contratos-publicos/13547...
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...  http://www.madrid.org/contratos-publicos/13548...
# https://contrataciondelestado.es/sindicacion/P...  http://www.madrid.org/contratos-publicos/13548...
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
#
#                                                   ContractFolderStatus - ProcurementProject - PlannedPeriod - StartDate  \
# id
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
#
#                                                   ContractFolderStatus - ProcurementProject - PlannedPeriod - EndDate  \
# id
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
#
#                                                    ContractFolderStatus - LocatedContractingParty - Party - PartyIdentification - ID  \
# id
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                          A12024974
#
#                                                   ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - ParentLocatedParty - PartyName - Name  \
# id
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                              Ayuntamiento de Leioa
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
#
#                                                   ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndDate  \
# id
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
#
#                                                   ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndTime  \
# id
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
# https://contrataciondelestado.es/sindicacion/P...                                               <NA>
#
#                                                   ContractFolderStatus - TenderResult - AwardedTenderedProject - ProcurementProjectLotID  \
# id
# https://contrataciondelestado.es/sindicacion/P...                                               None
# https://contrataciondelestado.es/sindicacion/P...                                               None
# https://contrataciondelestado.es/sindicacion/P...                                               None
# https://contrataciondelestado.es/sindicacion/P...                                               None
# https://contrataciondelestado.es/sindicacion/P...                                               None
#
#                                                   ContractFolderStatus - TenderingProcess - TenderSubmissionDeadlinePeriod
# id
# https://contrataciondelestado.es/sindicacion/P...                                                NaT
# https://contrataciondelestado.es/sindicacion/P...                          2020-01-23 17:00:00+00:00
# https://contrataciondelestado.es/sindicacion/P...                                                NaT
# https://contrataciondelestado.es/sindicacion/P...                                                NaT
# https://contrataciondelestado.es/sindicacion/P...                          2021-06-03 14:00:00+00:00
#
# [5 rows x 38 columns]

# %% [markdown]
# A function which keeps, for every procurement entry, only the last update.

# %%
#| export
def keep_updates_only(df: pd.DataFrame) -> pd.DataFrame:

    grouped = df.sort_values('updated').groupby('id')
    
    return grouped.tail(1)
    # return grouped.last()

# %%
len(post_df)
# Out:
# 117

# %%
only_updated_df = keep_updates_only(post_df)
only_updated_df.head()
# Out:
#                                                     id  \
# 116  https://contrataciondelestado.es/sindicacion/P...
# 115  https://contrataciondelestado.es/sindicacion/P...
# 114  https://contrataciondelestado.es/sindicacion/P...
# 113  https://contrataciondelestado.es/sindicacion/P...
# 112  https://contrataciondelestado.es/sindicacion/P...
#
#                                                summary  \
# 116  Id licitación: 0001264/2021; Órgano de contrat...
# 115  Id licitación: 8113_01 2021; Órgano de Contrat...
# 114  Id licitación: 8113_3/2021; Órgano de Contrata...
# 113  Id licitación: 8165_3/2021; Órgano de Contrata...
# 112  Id licitación: 1005_391-2021; Órgano de Contra...
#
#                                                  title  \
# 116  2021/pa-44-4 servicio de mantenimiento integra...
# 115  Contrato del Servicio de Teleasistencia para l...
# 114  Contrato de servicios de desinfección, desinse...
# 113  Asistencia técnica para la prestación del serv...
# 112  Apoyo a la gestión del patrimonio filmográfico...
#
#                              updated ContractFolderStatus - ContractFolderID  \
# 116 2021-12-30 23:14:15.739000+00:00                            0001264/2021
# 115 2021-12-31 00:00:12.604000+00:00                            8113_01 2021
# 114 2021-12-31 00:00:13.594000+00:00                             8113_3/2021
# 113 2021-12-31 00:00:14.393000+00:00                             8165_3/2021
# 112 2021-12-31 00:00:14.946000+00:00                           1005_391-2021
#
#     ContractFolderStatus - ContractFolderStatusCode  \
# 116                                             RES
# 115                                              EV
# 114                                              EV
# 113                                              EV
# 112                                             PUB
#
#     ContractFolderStatus - LocatedContractingParty - BuyerProfileURIID  \
# 116                                               <NA>
# 115                                               <NA>
# 114                                               <NA>
# 113                                               <NA>
# 112                                               <NA>
#
#     ContractFolderStatus - LocatedContractingParty - Party - PartyName - Name  \
# 116  Agencia Pública Empresarial Sanitaria Bajo Gua...
# 115  Agencia Navarra de Autonomía y Desarrollo de l...
# 114                  Subdirector de Gestión y Recursos
# 113  Mancomunidad de Servicios Sociales de Base de ...
# 112  Dirección General de Cultura-Institución Prínc...
#
#     ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - PartyName - Name  \
# 116                                 Junta de Andalucía
# 115                Agencia Navarra para la Dependencia
# 114                Agencia Navarra para la Dependencia
# 113  MANCOMUNIDAD DE SERVICIOS DE HUARTE Y DE ESTER...
# 112        Departamento de Cultura, Deporte y Juventud
#
#       ContractFolderStatus - ProcurementProject - Name  ...  \
# 116  2021/pa-44-4 servicio de mantenimiento integra...  ...
# 115  Contrato del Servicio de Teleasistencia para l...  ...
# 114  Contrato de servicios de desinfección, desinse...  ...
# 113  Asistencia técnica para la prestación del serv...  ...
# 112  Apoyo a la gestión del patrimonio filmográfico...  ...
#
#      ContractFolderStatus - TechnicalDocumentReference - ID  \
# 116                                               <NA>
# 115                                               <NA>
# 114                                               <NA>
# 113                                               <NA>
# 112                                               <NA>
#
#      ContractFolderStatus - TechnicalDocumentReference - Attachment - ExternalReference - URI  \
# 116                                               <NA>
# 115                                               <NA>
# 114                                               <NA>
# 113                                               <NA>
# 112                                               <NA>
#
#      ContractFolderStatus - ProcurementProject - PlannedPeriod - StartDate  \
# 116                                               <NA>
# 115                                               <NA>
# 114                                         2022-01-01
# 113                                               <NA>
# 112                                               <NA>
#
#     ContractFolderStatus - ProcurementProject - PlannedPeriod - EndDate  \
# 116                                               <NA>
# 115                                               <NA>
# 114                                         2022-12-31
# 113                                               <NA>
# 112                                               <NA>
#
#     ContractFolderStatus - LocatedContractingParty - Party - PartyIdentification - ID  \
# 116                                               <NA>
# 115                                               <NA>
# 114                                               <NA>
# 113                                               <NA>
# 112                                               <NA>
#
#      ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - ParentLocatedParty - PartyName - Name  \
# 116                                               <NA>
# 115                                               <NA>
# 114                                               <NA>
# 113                                               <NA>
# 112                                               <NA>
#
#     ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndDate  \
# 116                                               <NA>
# 115                                               <NA>
# 114                                               <NA>
# 113                                               <NA>
# 112                                               <NA>
#
#     ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndTime  \
# 116                                               <NA>
# 115                                               <NA>
# 114                                               <NA>
# 113                                               <NA>
# 112                                               <NA>
#
#     ContractFolderStatus - TenderResult - AwardedTenderedProject - ProcurementProjectLotID  \
# 116                                                NaN
# 115                                                NaN
# 114                                                NaN
# 113                                                NaN
# 112                                                NaN
#
#     ContractFolderStatus - TenderingProcess - TenderSubmissionDeadlinePeriod
# 116                          2021-11-11 15:00:00+00:00
# 115                                                NaT
# 114                                                NaT
# 113                                                NaT
# 112                          2022-01-14 23:59:00+00:00
#
# [5 rows x 39 columns]

# %%
len(only_updated_df)
# Out:
# 115

# %% [markdown]
# ## Deleted series

# %%
import sproc.bundle

# %%
zip_file = directory / 'yearly' / 'PlataformasAgregadasSinMenores_2018.zip'
assert zip_file.exists()
zip_file
# Out:
# PosixPath('/home/manu/Sync/UC3M/proyectos/2022/nextProcurement/sproc/samples/yearly/PlataformasAgregadasSinMenores_2018.zip')

# %%
deleted_series = sproc.bundle.read_deleted_zip(zip_file)
deleted_series.head(2)
# Out:
# zip                                      file name                                              id
# PlataformasAgregadasSinMenores_2018.zip  PlataformasAgregadasSinMenores_20180217_180137_1.atom  https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1985903   2018-01-04 13:11:18.021000+00:00
#                                                                                                 https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1969197   2018-01-04 13:11:17.921000+00:00
# Name: deleted_on, dtype: datetime64[ns, UTC]

# %% [markdown]
# No duplicates

# %%
deleted_series.index.get_level_values(1).duplicated().any()
# Out:
# True

# %% [markdown]
# We add an *artificial* one

# %%
new_data = pd.Timestamp(year=2017, month=1, day=3, tz=deleted_series[-1].tz)
deleted_series.loc['foo', deleted_series.index[-1][1], deleted_series.index[-1][2]] = new_data

# %% [markdown]
# Now have a duplicate (at *level* 1, i.e., `id`)

# %%
deleted_series.index.get_level_values(2).duplicated().any()
# Out:
# True

# %% [markdown]
# A function to get rid of duplicates from a *deleted series*. The **oldest** entry is kept.

# %%
#| export
def deduplicate_deleted_series(series: pd.Series) -> pd.Series:
    
    # return series.sort_values().groupby(axis=0, level='id', group_keys=False).nlargest(1)
    return series.sort_values().groupby(axis=0, level='id', group_keys=False).nsmallest(1)

# %%
deduplicated_series = deduplicate_deleted_series(deleted_series)
deduplicated_series.tail(2)
# Out:
# zip                                      file name                                              id
# PlataformasAgregadasSinMenores_2018.zip  PlataformasAgregadasSinMenores_20180217_190110_1.atom  https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1996094   2018-02-07 09:01:16.378000+00:00
# foo                                      PlataformasAgregadasSinMenores_20180217_190110_1.atom  https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/2000163          2017-01-03 00:00:00+00:00
# Name: deleted_on, dtype: datetime64[ns, UTC]

# %%
assert not deduplicated_series.index.get_level_values(2).duplicated().any()

# %%
deleted_series.shape, deduplicated_series.shape
# Out:
# ((52,), (51,))

# %% [markdown]
# ## Completeness

# %%
post_df
# Out:
#                                                     id  \
# 0    https://contrataciondelestado.es/sindicacion/P...
# 1    https://contrataciondelestado.es/sindicacion/P...
# 2    https://contrataciondelestado.es/sindicacion/P...
# 3    https://contrataciondelestado.es/sindicacion/P...
# 4    https://contrataciondelestado.es/sindicacion/P...
# ..                                                 ...
# 112  https://contrataciondelestado.es/sindicacion/P...
# 113  https://contrataciondelestado.es/sindicacion/P...
# 114  https://contrataciondelestado.es/sindicacion/P...
# 115  https://contrataciondelestado.es/sindicacion/P...
# 116  https://contrataciondelestado.es/sindicacion/P...
#
#                                                summary  \
# 0    Id licitación: C. 2-2021; Órgano de Contrataci...
# 1    Id licitación: 8128_3/2021; Órgano de Contrata...
# 2    Id licitación: 1000_0005-CP01-2021-000063; Órg...
# 3    Id licitación: 1379/2020 4738; Órgano de Contr...
# 4    Id licitación: 2021-44; Órgano de Contratación...
# ..                                                 ...
# 112  Id licitación: 1005_391-2021; Órgano de Contra...
# 113  Id licitación: 8165_3/2021; Órgano de Contrata...
# 114  Id licitación: 8113_3/2021; Órgano de Contrata...
# 115  Id licitación: 8113_01 2021; Órgano de Contrat...
# 116  Id licitación: 0001264/2021; Órgano de contrat...
#
#                                                  title  \
# 0    L'objecte del contracte és la renovació de tot...
# 1    Obras de restauración hidromorfológica del río...
# 2    Contrato del servicio de realización de labore...
# 3    Obres de renovació de l'enllumenat públic a la...
# 4    Subministre i la instal·lació fotovoltaica en ...
# ..                                                 ...
# 112  Apoyo a la gestión del patrimonio filmográfico...
# 113  Asistencia técnica para la prestación del serv...
# 114  Contrato de servicios de desinfección, desinse...
# 115  Contrato del Servicio de Teleasistencia para l...
# 116  2021/pa-44-4 servicio de mantenimiento integra...
#
#                              updated ContractFolderStatus - ContractFolderID  \
# 0   2022-01-03 00:11:41.826000+00:00                               C. 2-2021
# 1   2022-01-03 00:00:11.194000+00:00                             8128_3/2021
# 2   2022-01-03 00:00:10.399000+00:00              1000_0005-CP01-2021-000063
# 3   2022-01-02 23:11:40.740000+00:00                          1379/2020 4738
# 4   2022-01-02 23:11:40.696000+00:00                                 2021-44
# ..                               ...                                     ...
# 112 2021-12-31 00:00:14.946000+00:00                           1005_391-2021
# 113 2021-12-31 00:00:14.393000+00:00                             8165_3/2021
# 114 2021-12-31 00:00:13.594000+00:00                             8113_3/2021
# 115 2021-12-31 00:00:12.604000+00:00                            8113_01 2021
# 116 2021-12-30 23:14:15.739000+00:00                            0001264/2021
#
#     ContractFolderStatus - ContractFolderStatusCode  \
# 0                                               ADJ
# 1                                               PUB
# 2                                                EV
# 3                                                EV
# 4                                                EV
# ..                                              ...
# 112                                             PUB
# 113                                              EV
# 114                                              EV
# 115                                              EV
# 116                                             RES
#
#     ContractFolderStatus - LocatedContractingParty - BuyerProfileURIID  \
# 0    https://contractaciopublica.gencat.cat/ecofin_...
# 1                                                 <NA>
# 2                                                 <NA>
# 3    https://contractaciopublica.gencat.cat/ecofin_...
# 4    https://contractaciopublica.gencat.cat/ecofin_...
# ..                                                 ...
# 112                                               <NA>
# 113                                               <NA>
# 114                                               <NA>
# 115                                               <NA>
# 116                                               <NA>
#
#     ContractFolderStatus - LocatedContractingParty - Party - PartyName - Name  \
# 0                             Ajuntament de Sant Ramon
# 1                               Pleno del Ayuntamiento
# 2    El Director General de Comunicación y Relacion...
# 3                           Ajuntament de Canet de Mar
# 4                                  Ajuntament de Valls
# ..                                                 ...
# 112  Dirección General de Cultura-Institución Prínc...
# 113  Mancomunidad de Servicios Sociales de Base de ...
# 114                  Subdirector de Gestión y Recursos
# 115  Agencia Navarra de Autonomía y Desarrollo de l...
# 116  Agencia Pública Empresarial Sanitaria Bajo Gua...
#
#     ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - PartyName - Name  \
# 0                     Entitats municipals de Catalunya
# 1                              AYUNTAMIENTO DE MONREAL
# 2    Departamento de Presidencia, Igualdad, Función...
# 3                     Entitats municipals de Catalunya
# 4                     Entitats municipals de Catalunya
# ..                                                 ...
# 112        Departamento de Cultura, Deporte y Juventud
# 113  MANCOMUNIDAD DE SERVICIOS DE HUARTE Y DE ESTER...
# 114                Agencia Navarra para la Dependencia
# 115                Agencia Navarra para la Dependencia
# 116                                 Junta de Andalucía
#
#       ContractFolderStatus - ProcurementProject - Name  ...  \
# 0    L'objecte del contracte és la renovació de tot...  ...
# 1    Obras de restauración hidromorfológica del río...  ...
# 2    Contrato del servicio de realización de labore...  ...
# 3    Obres de renovació de l'enllumenat públic a la...  ...
# 4    Subministre i la instal·lació fotovoltaica en ...  ...
# ..                                                 ...  ...
# 112  Apoyo a la gestión del patrimonio filmográfico...  ...
# 113  Asistencia técnica para la prestación del serv...  ...
# 114  Contrato de servicios de desinfección, desinse...  ...
# 115  Contrato del Servicio de Teleasistencia para l...  ...
# 116  2021/pa-44-4 servicio de mantenimiento integra...  ...
#
#      ContractFolderStatus - TechnicalDocumentReference - ID  \
# 0                                                 <NA>
# 1                                                 <NA>
# 2                                                 <NA>
# 3                                                 <NA>
# 4                  Enllac plec clausules tecniques.doc
# ..                                                 ...
# 112                                               <NA>
# 113                                               <NA>
# 114                                               <NA>
# 115                                               <NA>
# 116                                               <NA>
#
#      ContractFolderStatus - TechnicalDocumentReference - Attachment - ExternalReference - URI  \
# 0                                                 <NA>
# 1                                                 <NA>
# 2                                                 <NA>
# 3                                                 <NA>
# 4    https://contractaciopublica.gencat.cat/ecofin_...
# ..                                                 ...
# 112                                               <NA>
# 113                                               <NA>
# 114                                               <NA>
# 115                                               <NA>
# 116                                               <NA>
#
#      ContractFolderStatus - ProcurementProject - PlannedPeriod - StartDate  \
# 0                                                 <NA>
# 1                                                 <NA>
# 2                                                 <NA>
# 3                                                 <NA>
# 4                                                 <NA>
# ..                                                 ...
# 112                                               <NA>
# 113                                               <NA>
# 114                                         2022-01-01
# 115                                               <NA>
# 116                                               <NA>
#
#     ContractFolderStatus - ProcurementProject - PlannedPeriod - EndDate  \
# 0                                                 <NA>
# 1                                                 <NA>
# 2                                                 <NA>
# 3                                                 <NA>
# 4                                                 <NA>
# ..                                                 ...
# 112                                               <NA>
# 113                                               <NA>
# 114                                         2022-12-31
# 115                                               <NA>
# 116                                               <NA>
#
#     ContractFolderStatus - LocatedContractingParty - Party - PartyIdentification - ID  \
# 0                                                 <NA>
# 1                                                 <NA>
# 2                                                 <NA>
# 3                                                 <NA>
# 4                                                 <NA>
# ..                                                 ...
# 112                                               <NA>
# 113                                               <NA>
# 114                                               <NA>
# 115                                               <NA>
# 116                                               <NA>
#
#      ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - ParentLocatedParty - PartyName - Name  \
# 0                                                 <NA>
# 1                                                 <NA>
# 2                                                 <NA>
# 3                                                 <NA>
# 4                                                 <NA>
# ..                                                 ...
# 112                                               <NA>
# 113                                               <NA>
# 114                                               <NA>
# 115                                               <NA>
# 116                                               <NA>
#
#     ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndDate  \
# 0                                                 <NA>
# 1                                                 <NA>
# 2                                                 <NA>
# 3                                                 <NA>
# 4                                                 <NA>
# ..                                                 ...
# 112                                               <NA>
# 113                                               <NA>
# 114                                               <NA>
# 115                                               <NA>
# 116                                               <NA>
#
#     ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndTime  \
# 0                                                 <NA>
# 1                                                 <NA>
# 2                                                 <NA>
# 3                                                 <NA>
# 4                                                 <NA>
# ..                                                 ...
# 112                                               <NA>
# 113                                               <NA>
# 114                                               <NA>
# 115                                               <NA>
# 116                                               <NA>
#
#     ContractFolderStatus - TenderResult - AwardedTenderedProject - ProcurementProjectLotID  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
# 116                                                NaN
#
#     ContractFolderStatus - TenderingProcess - TenderSubmissionDeadlinePeriod
# 0                            2021-12-17 14:00:00+00:00
# 1                            2022-01-22 23:30:00+00:00
# 2                                                  NaT
# 3                            2022-01-02 23:59:00+00:00
# 4                            2022-01-02 23:59:00+00:00
# ..                                                 ...
# 112                          2022-01-14 23:59:00+00:00
# 113                                                NaT
# 114                                                NaT
# 115                                                NaT
# 116                          2021-11-11 15:00:00+00:00
#
# [117 rows x 39 columns]

# %%
#| hide
from nbdev.doclinks import nbdev_export

# %%
#| hide
nbdev_export('15_postprocess.ipynb')
