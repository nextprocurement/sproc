# %%
#| default_exp bundle

# %% [markdown]
# # bundle
#
# > Functionality to deal with multiple XML files

# %%
#| export
import pathlib
import zipfile

import pandas as pd

import sproc.structure
import sproc.xml

# %% [markdown]
# Some handy imports that are not actually required by the library.

# %%
from IPython.display import display

# %% [markdown]
# Directory where the zip files are stored

# %%
directory = pathlib.Path.cwd().parent / 'samples'
assert directory.exists()
directory
# Out:
# PosixPath('/home/manu/Sync/UC3M/proyectos/2022/nextProcurement/sproc/samples')

# %% [markdown]
# ### Zip file

# %% [markdown]
# A (sample) file in that directory

# %%
input_file = directory / 'PlataformasAgregadasSinMenores_202201_05-06.zip'
assert input_file.exists()
input_file
# Out:
# PosixPath('/home/manu/Sync/UC3M/proyectos/2022/nextProcurement/sproc/samples/PlataformasAgregadasSinMenores_202201_05-06.zip')

# %% [markdown]
# A function to read **all** the *XML* files contained in a given zip file.

# %%
#| export
def read_zip(
    input_file: str | pathlib.Path, # Input file
    concatenate: bool = False, # If `True` all the files are concatenated in a single `pd.DataFrame`
    return_filenames: bool = False # If `True` the names of the files (read) within the zip are returned too
) -> list | pd.DataFrame | tuple[list, list] | tuple[pd.DataFrame, list]: # XML data
    "Reads and parses an XML file into a `pd.DataFrame`"

    # in case a `str` was passed
    input_file = pathlib.Path(input_file)
    
    dfs = []
    
    # zip file is opened
    with zipfile.ZipFile(input_file) as zip_file:
        
        # for the sake of convenience
        filenames = zip_file.namelist()
        
        # every file within it...
        for name in filenames:
            
            # ...is opened...
            with zip_file.open(name) as f:
                
                # ...and processed
                dfs.append(sproc.xml.to_curated_df(f))
    
    if concatenate:
        
        # dfs = pd.concat(dfs, keys=filenames, names=['file name', 'entry'])

        dfs = pd.concat(dfs, keys=pd.MultiIndex.from_product(([input_file.name], filenames)), names=['zip', 'file name', 'entry'])
    
    if return_filenames:
        
        return dfs, filenames
    
    else:
        
        return dfs

# %%
dfs_zip = read_zip(input_file)
print(f'{len(dfs_zip)=}')
dfs_zip[0].head(3)
# Out:
# len(dfs_zip)=2
#                                                   id  \
# 0  https://contrataciondelestado.es/sindicacion/P...
# 1  https://contrataciondelestado.es/sindicacion/P...
# 2  https://contrataciondelestado.es/sindicacion/P...
#
#                                              summary  \
# 0  Id licitación: 2021039438; Órgano de Contratac...
# 1  Id licitación: 2021_2568; Órgano de Contrataci...
# 2  Id licitación: 12450/2021; Órgano de Contratac...
#
#                                                title  \
# 0  L'objecte és la contractació del servei de bug...
# 1  Servei comunicacions postals de l'Ajuntament d...
# 2  L'objecte del contracte és l'execució de les o...
#
#                            updated ContractFolderStatus - ContractFolderID  \
# 0 2022-01-04 12:12:09.464000+00:00                              2021039438
# 1 2022-01-04 12:12:09.400000+00:00                               2021_2568
# 2 2022-01-04 12:12:09.343000+00:00                              12450/2021
#
#   ContractFolderStatus - ContractFolderStatusCode  \
# 0                                             RES
# 1                                             ADJ
# 2                                             ADJ
#
#   ContractFolderStatus - LocatedContractingParty - BuyerProfileURIID  \
# 0  https://contractaciopublica.gencat.cat/ecofin_...
# 1  https://contractaciopublica.gencat.cat/ecofin_...
# 2  https://contractaciopublica.gencat.cat/ecofin_...
#
#   ContractFolderStatus - LocatedContractingParty - Party - PartyName - Name  \
# 0                               Ajuntament de Girona
# 1                             Ajuntament de Collbató
# 2                   Ajuntament de Mont-roig del Camp
#
#   ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - PartyName - Name  \
# 0                   Entitats municipals de Catalunya
# 1                   Entitats municipals de Catalunya
# 2                   Entitats municipals de Catalunya
#
#     ContractFolderStatus - ProcurementProject - Name  ...  \
# 0  L'objecte és la contractació del servei de bug...  ...
# 1  Servei comunicacions postals de l'Ajuntament d...  ...
# 2  L'objecte del contracte és l'execució de les o...  ...
#
#    ContractFolderStatus - ProcurementProject - PlannedPeriod - StartDate  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
#
#    ContractFolderStatus - LegalDocumentReference - ID  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
#
#    ContractFolderStatus - LegalDocumentReference - Attachment - ExternalReference - URI  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
#
#   ContractFolderStatus - ProcurementProject - PlannedPeriod - EndDate  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
#
#   ContractFolderStatus - TechnicalDocumentReference - ID  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
#
#    ContractFolderStatus - TechnicalDocumentReference - Attachment - ExternalReference - URI  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
#
#   ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - ParentLocatedParty - PartyName - Name  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
#
#   ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndDate  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
#
#    ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndTime  \
# 0                                               <NA>
# 1                                               <NA>
# 2                                               <NA>
#
#   ContractFolderStatus - TenderingProcess - TenderSubmissionDeadlinePeriod
# 0                          2021-12-13 23:59:00+00:00
# 1                          2021-11-29 23:59:00+00:00
# 2                          2021-12-20 14:00:00+00:00
#
# [3 rows x 39 columns]

# %% [markdown]
# A single `pd.DataFrame` encompassing all the files in the zip can be returned (file names are used as the top-level index)

# %%
dfs_concatenated_zip = read_zip(input_file, concatenate=True)
dfs_concatenated_zip
# Out:
#                                                                                                                                                          id  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0      https://contrataciondelestado.es/sindicacion/P...
#                                                                                                    1      https://contrataciondelestado.es/sindicacion/P...
#                                                                                                    2      https://contrataciondelestado.es/sindicacion/P...
#                                                                                                    3      https://contrataciondelestado.es/sindicacion/P...
#                                                                                                    4      https://contrataciondelestado.es/sindicacion/P...
# ...                                                                                                                                                     ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471    https://contrataciondelestado.es/sindicacion/P...
#                                                                                                    472    https://contrataciondelestado.es/sindicacion/P...
#                                                                                                    473    https://contrataciondelestado.es/sindicacion/P...
#                                                                                                    474    https://contrataciondelestado.es/sindicacion/P...
#                                                                                                    475    https://contrataciondelestado.es/sindicacion/P...
#
#                                                                                                                                                     summary  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0      Id licitación: 2021039438; Órgano de Contratac...
#                                                                                                    1      Id licitación: 2021_2568; Órgano de Contrataci...
#                                                                                                    2      Id licitación: 12450/2021; Órgano de Contratac...
#                                                                                                    3      Id licitación: 2021/14/M0400100; Órgano de Con...
#                                                                                                    4      Id licitación: ICVI-2022-1; Órgano de Contrata...
# ...                                                                                                                                                     ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471    Id licitación: 2021/57-12334; Órgano de Contra...
#                                                                                                    472    Id licitación: 32/2021; Órgano de Contratación...
#                                                                                                    473    Id licitación: 1977/2021; Órgano de Contrataci...
#                                                                                                    474    Id licitación: EXI-2022-7; Órgano de Contratac...
#                                                                                                    475    Id licitación: CONTR/2021/000000137; Órgano de...
#
#                                                                                                                                                       title  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0      L'objecte és la contractació del servei de bug...
#                                                                                                    1      Servei comunicacions postals de l'Ajuntament d...
#                                                                                                    2      L'objecte del contracte és l'execució de les o...
#                                                                                                    3      El serveiobjecte del contracte és la difusió p...
#                                                                                                    4      Servei de neteja de les instal·lacions de l'IN...
# ...                                                                                                                                                     ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471    L'objecte d'aquest contracte és la prestació c...
#                                                                                                    472    Licitació per procediment obert harmonitzat i ...
#                                                                                                    473    L'objecte d'aquest contracte és la prestació d...
#                                                                                                    474    Servei de trasllat de béns mobles( mobiliari, ...
#                                                                                                    475    Servei de redacció del Projecte Executiu d'obr...
#
#                                                                                                                                   updated  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0     2022-01-04 12:12:09.464000+00:00
#                                                                                                    1     2022-01-04 12:12:09.400000+00:00
#                                                                                                    2     2022-01-04 12:12:09.343000+00:00
#                                                                                                    3     2022-01-04 12:12:09.285000+00:00
#                                                                                                    4     2022-01-04 12:12:09.227000+00:00
# ...                                                                                                                                   ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471   2022-01-04 12:12:09.949000+00:00
#                                                                                                    472   2022-01-04 12:12:09.742000+00:00
#                                                                                                    473   2022-01-04 12:12:09.666000+00:00
#                                                                                                    474   2022-01-04 12:12:09.602000+00:00
#                                                                                                    475   2022-01-04 12:12:09.536000+00:00
#
#                                                                                                          ContractFolderStatus - ContractFolderID  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0                                  2021039438
#                                                                                                    1                                   2021_2568
#                                                                                                    2                                  12450/2021
#                                                                                                    3                            2021/14/M0400100
#                                                                                                    4                                 ICVI-2022-1
# ...                                                                                                                                          ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471                             2021/57-12334
#                                                                                                    472                                   32/2021
#                                                                                                    473                                 1977/2021
#                                                                                                    474                                EXI-2022-7
#                                                                                                    475                      CONTR/2021/000000137
#
#                                                                                                          ContractFolderStatus - ContractFolderStatusCode  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0                                                 RES
#                                                                                                    1                                                 ADJ
#                                                                                                    2                                                 ADJ
#                                                                                                    3                                                 ADJ
#                                                                                                    4                                                 ADJ
# ...                                                                                                                                                  ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471                                               PUB
#                                                                                                    472                                               RES
#                                                                                                    473                                               RES
#                                                                                                    474                                               ADJ
#                                                                                                    475                                               ADJ
#
#                                                                                                          ContractFolderStatus - LocatedContractingParty - BuyerProfileURIID  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0      https://contractaciopublica.gencat.cat/ecofin_...
#                                                                                                    1      https://contractaciopublica.gencat.cat/ecofin_...
#                                                                                                    2      https://contractaciopublica.gencat.cat/ecofin_...
#                                                                                                    3      https://contractaciopublica.gencat.cat/ecofin_...
#                                                                                                    4      https://contractaciopublica.gencat.cat/ecofin_...
# ...                                                                                                                                                     ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471    https://contractaciopublica.gencat.cat/ecofin_...
#                                                                                                    472    https://contractaciopublica.gencat.cat/ecofin_...
#                                                                                                    473    https://contractaciopublica.gencat.cat/ecofin_...
#                                                                                                    474    https://contractaciopublica.gencat.cat/ecofin_...
#                                                                                                    475    https://contractaciopublica.gencat.cat/ecofin_...
#
#                                                                                                          ContractFolderStatus - LocatedContractingParty - Party - PartyName - Name  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0                                   Ajuntament de Girona
#                                                                                                    1                                 Ajuntament de Collbató
#                                                                                                    2                       Ajuntament de Mont-roig del Camp
#                                                                                                    3                              Casa de Cultura de Girona
#                                                                                                    4           Institut Català de la Vinya i el Vi (INCAVI)
# ...                                                                                                                                                     ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471               Ajuntament de Palau-solità i Plegamans
#                                                                                                    472                  Consell Comarcal del Baix Llobregat
#                                                                                                    473                    Ajuntament de Sant Adrià de Besòs
#                                                                                                    474          Departament d'Acció Exterior i Govern Obert
#                                                                                                    475               Institut d'Assistència Sanitària (IAS)
#
#                                                                                                          ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - PartyName - Name  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0                       Entitats municipals de Catalunya
#                                                                                                    1                       Entitats municipals de Catalunya
#                                                                                                    2                       Entitats municipals de Catalunya
#                                                                                                    3                       Entitats municipals de Catalunya
#                                                                                                    4         Departaments i Sector Públic de la Generalitat
# ...                                                                                                                                                     ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471                     Entitats municipals de Catalunya
#                                                                                                    472                     Entitats municipals de Catalunya
#                                                                                                    473                     Entitats municipals de Catalunya
#                                                                                                    474       Departaments i Sector Públic de la Generalitat
#                                                                                                    475       Departaments i Sector Públic de la Generalitat
#
#                                                                                                            ContractFolderStatus - ProcurementProject - Name  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0      L'objecte és la contractació del servei de bug...
#                                                                                                    1      Servei comunicacions postals de l'Ajuntament d...
#                                                                                                    2      L'objecte del contracte és l'execució de les o...
#                                                                                                    3      El serveiobjecte del contracte és la difusió p...
#                                                                                                    4      Servei de neteja de les instal·lacions de l'IN...
# ...                                                                                                                                                     ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471    L'objecte d'aquest contracte és la prestació c...
#                                                                                                    472    Licitació per procediment obert harmonitzat i ...
#                                                                                                    473    L'objecte d'aquest contracte és la prestació d...
#                                                                                                    474    Servei de trasllat de béns mobles( mobiliari, ...
#                                                                                                    475    Servei de redacció del Projecte Executiu d'obr...
#
#                                                                                                           ...  \
# zip                                             file name                                          entry  ...
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0      ...
#                                                                                                    1      ...
#                                                                                                    2      ...
#                                                                                                    3      ...
#                                                                                                    4      ...
# ...                                                                                                       ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471    ...
#                                                                                                    472    ...
#                                                                                                    473    ...
#                                                                                                    474    ...
#                                                                                                    475    ...
#
#                                                                                                           ContractFolderStatus - ProcurementProject - PlannedPeriod - StartDate  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0                                                   <NA>
#                                                                                                    1                                                   <NA>
#                                                                                                    2                                                   <NA>
#                                                                                                    3                                                   <NA>
#                                                                                                    4                                                   <NA>
# ...                                                                                                                                                     ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471                                                 <NA>
#                                                                                                    472                                                 <NA>
#                                                                                                    473                                                 <NA>
#                                                                                                    474                                                 <NA>
#                                                                                                    475                                                 <NA>
#
#                                                                                                           ContractFolderStatus - LegalDocumentReference - ID  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0                                                   <NA>
#                                                                                                    1                                                   <NA>
#                                                                                                    2                                                   <NA>
#                                                                                                    3                                                   <NA>
#                                                                                                    4                                                   <NA>
# ...                                                                                                                                                     ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471    PCAP subminist. 8 cameres videovigilancia 2021...
#                                                                                                    472                                                 <NA>
#                                                                                                    473                                                 <NA>
#                                                                                                    474                                                 <NA>
#                                                                                                    475                                                 <NA>
#
#                                                                                                           ContractFolderStatus - LegalDocumentReference - Attachment - ExternalReference - URI  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0                                                   <NA>
#                                                                                                    1                                                   <NA>
#                                                                                                    2                                                   <NA>
#                                                                                                    3                                                   <NA>
#                                                                                                    4                                                   <NA>
# ...                                                                                                                                                     ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471    https://contractaciopublica.gencat.cat/ecofin_...
#                                                                                                    472                                                 <NA>
#                                                                                                    473                                                 <NA>
#                                                                                                    474                                                 <NA>
#                                                                                                    475                                                 <NA>
#
#                                                                                                          ContractFolderStatus - ProcurementProject - PlannedPeriod - EndDate  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0                                                   <NA>
#                                                                                                    1                                                   <NA>
#                                                                                                    2                                                   <NA>
#                                                                                                    3                                                   <NA>
#                                                                                                    4                                                   <NA>
# ...                                                                                                                                                     ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471                                                 <NA>
#                                                                                                    472                                                 <NA>
#                                                                                                    473                                                 <NA>
#                                                                                                    474                                                 <NA>
#                                                                                                    475                                                 <NA>
#
#                                                                                                          ContractFolderStatus - TechnicalDocumentReference - ID  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0                                                   <NA>
#                                                                                                    1                                                   <NA>
#                                                                                                    2                                                   <NA>
#                                                                                                    3                                                   <NA>
#                                                                                                    4                                                   <NA>
# ...                                                                                                                                                     ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471    PPT_subministrament 8 cameres videovigilancia_...
#                                                                                                    472                                                 <NA>
#                                                                                                    473                                                 <NA>
#                                                                                                    474                                                 <NA>
#                                                                                                    475                                                 <NA>
#
#                                                                                                           ContractFolderStatus - TechnicalDocumentReference - Attachment - ExternalReference - URI  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0                                                   <NA>
#                                                                                                    1                                                   <NA>
#                                                                                                    2                                                   <NA>
#                                                                                                    3                                                   <NA>
#                                                                                                    4                                                   <NA>
# ...                                                                                                                                                     ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471    https://contractaciopublica.gencat.cat/ecofin_...
#                                                                                                    472                                                 <NA>
#                                                                                                    473                                                 <NA>
#                                                                                                    474                                                 <NA>
#                                                                                                    475                                                 <NA>
#
#                                                                                                          ContractFolderStatus - LocatedContractingParty - ParentLocatedParty - ParentLocatedParty - PartyName - Name  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0                                                   <NA>
#                                                                                                    1                                                   <NA>
#                                                                                                    2                                                   <NA>
#                                                                                                    3                                                   <NA>
#                                                                                                    4                                                   <NA>
# ...                                                                                                                                                     ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471                                                 <NA>
#                                                                                                    472                                                 <NA>
#                                                                                                    473                                                 <NA>
#                                                                                                    474                                                 <NA>
#                                                                                                    475                                                 <NA>
#
#                                                                                                          ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndDate  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0                                                   <NA>
#                                                                                                    1                                                   <NA>
#                                                                                                    2                                                   <NA>
#                                                                                                    3                                                   <NA>
#                                                                                                    4                                                   <NA>
# ...                                                                                                                                                     ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471                                                 <NA>
#                                                                                                    472                                                 <NA>
#                                                                                                    473                                                 <NA>
#                                                                                                    474                                                 <NA>
#                                                                                                    475                                                 <NA>
#
#                                                                                                           ContractFolderStatus - TenderingProcess - ParticipationRequestReceptionPeriod - EndTime  \
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0                                                   <NA>
#                                                                                                    1                                                   <NA>
#                                                                                                    2                                                   <NA>
#                                                                                                    3                                                   <NA>
#                                                                                                    4                                                   <NA>
# ...                                                                                                                                                     ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471                                                 <NA>
#                                                                                                    472                                                 <NA>
#                                                                                                    473                                                 <NA>
#                                                                                                    474                                                 <NA>
#                                                                                                    475                                                 <NA>
#
#                                                                                                          ContractFolderStatus - TenderingProcess - TenderSubmissionDeadlinePeriod
# zip                                             file name                                          entry
# PlataformasAgregadasSinMenores_202201_05-06.zip PlataformasAgregadasSinMenores_20220105_030012.... 0                              2021-12-13 23:59:00+00:00
#                                                                                                    1                              2021-11-29 23:59:00+00:00
#                                                                                                    2                              2021-12-20 14:00:00+00:00
#                                                                                                    3                              2021-10-22 14:00:00+00:00
#                                                                                                    4                              2021-11-30 18:00:00+00:00
# ...                                                                                                                                                     ...
#                                                 PlataformasAgregadasSinMenores_20220106_030013.... 471                            2022-01-19 15:00:00+00:00
#                                                                                                    472                            2021-05-07 15:00:00+00:00
#                                                                                                    473                            2021-06-30 23:59:00+00:00
#                                                                                                    474                            2021-12-13 13:00:00+00:00
#                                                                                                    475                            2021-11-10 18:00:00+00:00
#
# [951 rows x 39 columns]

# %%
dfs_concatenated_zip.dtypes[:4]
# Out:
# id                      string
# summary                 string
# title                   string
# updated    datetime64[ns, UTC]
# dtype: object

# %% [markdown]
# Filenames can also be requested

# %%
_, filenames = read_zip(input_file, return_filenames=True)
print(filenames)
# Out:
# ['PlataformasAgregadasSinMenores_20220105_030012.atom', 'PlataformasAgregadasSinMenores_20220106_030013.atom']

# %% [markdown]
# #### Deleted entries

# %%
#| export
def read_deleted_zip(
    input_file: str | pathlib.Path # Input file
    ) -> pd.Series: # XML data
    "Reads and parses an XML file into a `pd.DataFrame`"
    
    series = []

    # in case a `str` was passed
    input_file = pathlib.Path(input_file)
    
    # zip file is opened
    with zipfile.ZipFile(input_file) as zip_file:
        
        # for the sake of convenience
        filenames = zip_file.namelist()
        
        # every file within it...
        for name in filenames:
            
            # ...is opened...
            with zip_file.open(name) as f:
                
                # ...and processed
                series.append(sproc.xml.deleted_to_series(f))

    return pd.concat(series, keys=pd.MultiIndex.from_product(([input_file.name], filenames)), names=['zip', 'file name', 'id'])
    # return pd.concat(series, keys=filenames, names=['file name', 'id'])

# %%
read_deleted_zip(input_file)
# Out:
# zip                                              file name                                            id
# PlataformasAgregadasSinMenores_202201_05-06.zip  PlataformasAgregadasSinMenores_20220105_030012.atom  https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/6724977   2022-01-04 00:12:01.376000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968315   2022-01-03 23:11:57.567000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968345   2022-01-03 23:11:57.516000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968324   2022-01-03 23:11:57.471000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968344   2022-01-03 23:11:57.426000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968337   2022-01-03 23:11:57.375000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968321   2022-01-03 23:11:57.323000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968335   2022-01-03 23:11:57.275000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968343   2022-01-03 23:11:57.232000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968333   2022-01-03 23:11:57.183000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968360   2022-01-03 23:11:57.141000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968327   2022-01-03 23:11:57.089000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968318   2022-01-03 23:11:57.038000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968361   2022-01-03 23:11:56.991000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968332   2022-01-03 23:11:56.949000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968331   2022-01-03 23:11:56.897000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968329   2022-01-03 23:11:56.850000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968338   2022-01-03 23:11:56.805000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968317   2022-01-03 23:11:56.751000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968358   2022-01-03 23:11:56.706000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968346   2022-01-03 23:11:56.661000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968319   2022-01-03 23:11:56.620000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968325   2022-01-03 23:11:56.579000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1957921   2022-01-03 23:11:56.535000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1959074   2022-01-03 23:11:56.497000+00:00
#                                                  PlataformasAgregadasSinMenores_20220106_030013.atom  https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968294   2022-01-04 23:12:13.328000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968301   2022-01-04 23:12:13.283000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968299   2022-01-04 23:12:13.236000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968291   2022-01-04 23:12:13.191000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968286   2022-01-04 23:12:13.147000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968282   2022-01-04 23:12:13.107000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968303   2022-01-04 23:12:13.058000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968269   2022-01-04 23:12:13.013000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968272   2022-01-04 23:12:12.957000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968284   2022-01-04 23:12:12.911000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968280   2022-01-04 23:12:12.865000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968285   2022-01-04 23:12:12.819000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968267   2022-01-04 23:12:12.775000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968268   2022-01-04 23:12:12.731000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968302   2022-01-04 23:12:12.680000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968290   2022-01-04 23:12:12.635000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968271   2022-01-04 23:12:12.172000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968289   2022-01-04 23:12:12.129000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968305   2022-01-04 23:12:12.076000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968279   2022-01-04 23:12:12.039000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968287   2022-01-04 23:12:11.998000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968288   2022-01-04 23:12:11.957000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/1968266   2022-01-04 23:12:11.916000+00:00
#                                                                                                       https://contrataciondelestado.es/sindicacion/PlataformasAgregadasSinMenores/8892704   2022-01-04 13:13:12.670000+00:00
# Name: deleted_on, dtype: datetime64[ns, UTC]

# %% [markdown]
# ## Extra tests

# %%
# %%script false --no-raise-error
#
# # data_file = pathlib.Path.cwd() / 'data' / 'agregados'
# # data_file /= 'PlataformasAgregadasSinMenores_202201.zip'
# # data_file /= 'PlataformasAgregadasSinMenores_202202.zip'
# # data_file /= 'PlataformasAgregadasSinMenores_202203.zip'
#
#
# data_file = pathlib.Path.cwd() / 'data' / 'perfiles_plataforma'
# data_file /= 'licitacionesPerfilesContratanteCompleto3_202201.zip'

# %%
# %%script false --no-raise-error
#
# df = read_zip(data_file, concatenate=True)
# df.shape

# %%
# %%script false --no-raise-error
#
# df['ContractFolderStatus - ProcurementProject - BudgetAmount - TotalAmount'].dtype

# %%
# %%script false --no-raise-error
#
# grouping_col = sproc.structure.assemble_name(['ContractFolderStatus', 'LocatedContractingParty', 'Party', 'PartyName', 'Name'])
# grouping_col

# %%
# %%script false --no-raise-error
#
# amount_col = sproc.structure.assemble_name(['ContractFolderStatus', 'ProcurementProject', 'BudgetAmount', 'TotalAmount'])
# amount_col

# %%
# %%script false --no-raise-error
#
# df.groupby(grouping_col).agg(money=(amount_col, 'sum'), n=(amount_col, 'size'))

# %%
#| hide
from nbdev.doclinks import nbdev_export

# %%
#| hide
nbdev_export('20_bundle.ipynb')
